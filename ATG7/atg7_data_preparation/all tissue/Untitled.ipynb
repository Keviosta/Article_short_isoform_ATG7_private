# %%
import pandas

# %%
input_file_directory = '/Users/kja11/OneDrive - Háskóli Íslands/PhD ATG7//0 in_silico/Python/1)data_input/'
output_file_directory = '/Users/kja11/OneDrive - Háskóli Íslands/PhD ATG7/0 in_silico/Python/3)output/'

# %%
path = output_file_directory + "ATG7/TCGA_GTEX/all_tissues/"
path2 = 'dataframes_for_input/'

# %%
# %%time
# DL data ATG7 isoform expression
df1 = pandas.read_csv(path+path2+'ensembl_primary_atg7_proteinGE.tsv', sep = "\t")
df2 = pandas.read_csv(path+path2+'ensembl_normal_atg7_proteinGE.tsv', sep = "\t")
print(df1.shape)
print(df2.shape)
# Out:
# (8022, 19384)
# (5847, 19384)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'dffff' is not defined

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (8022, 19384)
# (5847, 19384)

# %%
df1
# Out:
#         Sample_Type   Primary_Site      ATG7    ATG7_1    ATG7_2  \
# 0     Primary Tumor  Adrenal Gland  4.874006  3.384104  2.244552
# 1     Primary Tumor  Adrenal Gland  4.841178  4.140146  1.686916
# 2     Primary Tumor  Adrenal Gland  4.816092  4.629437  0.400624
# 3     Primary Tumor  Adrenal Gland  4.803555  4.291540  0.201684
# 4     Primary Tumor  Adrenal Gland  4.658238  3.223226  2.978529
# ...             ...            ...       ...       ...       ...
# 8017  Primary Tumor            Eye  3.309256  2.575620  0.687044
# 8018  Primary Tumor            Eye  3.216976  2.961951  0.411450
# 8019  Primary Tumor            Eye  3.187558  2.367427  0.696007
# 8020  Primary Tumor            Eye  3.089155  2.759308  0.000000
# 8021  Primary Tumor            Eye  3.028428  2.715947  0.000000
#
#       ENSG00000198712  ENSG00000228253  ENSG00000198899  ENSG00000198938  \
# 0           15.296136        15.090641        14.623957        15.058642
# ...
