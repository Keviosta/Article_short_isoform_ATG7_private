# %%
import pandas

# %%
input_file_directory_gene_expr = '/Users/kja11/OneDrive - Háskóli Íslands/PhD ATG7/0 Python Analysis/gene_expr_preparation/'

# %% [markdown]
# ## functions & options

# %%
output_file_directory = '/Users/kja11/OneDrive - Háskóli Íslands/PhD ATG7/0 in_silico/Python/3)output/'

# %%
input_file_directory = '/Users/kja11/OneDrive - Háskóli Íslands/PhD ATG7//0 in_silico/Python/1)data_input/'

# %%
#define a function to split after the ".". The 1 is for how many word to have. if we have several dot. The [1] is what is after the dot, and [0] what is before
def split(L):
  return L.split(".",1)[0]

# %% [markdown]
# # II] Dataframe settings

# %%
# %%time
path = input_file_directory + "protein_coding_list.txt"
protein_coding_list= pandas.read_csv(path, sep = "\t")
print(protein_coding_list.shape)
protein_coding_list.head()
# Out:
# (22796, 4)
# Wall time: 32.9 ms
#    ensembl_gene_id hgnc_symbol  entrezgene_id transcript_biotype
# 1  ENSG00000198888      MT-ND1         4535.0     protein_coding
# 2  ENSG00000198763      MT-ND2         4536.0     protein_coding
# 3  ENSG00000198804      MT-CO1         4512.0     protein_coding
# 4  ENSG00000198712      MT-CO2         4513.0     protein_coding
# 5  ENSG00000228253     MT-ATP8         4509.0     protein_coding

# %%
print("is nan in ensembl:", protein_coding_list['ensembl_gene_id'].isna().sum())
print("is nan in hgnc_symbol:", protein_coding_list['hgnc_symbol'].isna().sum())
print("is nan in entrezgene_id:", protein_coding_list['entrezgene_id'].isna().sum())

# %%
# %%time
#Download the sample labels for normal and primary
path = input_file_directory + "/samples_IDs/samples_normal_tissue.tsv"
normal_tissue_IDs = pandas.read_csv(path, sep = "\t")

path = input_file_directory + "/samples_IDs/samples_primary_tumors.tsv"
primary_tumor_IDs = pandas.read_csv(path, sep = "\t")

print(protein_coding_list.shape)
protein_coding_list.head()
# Out:
# (22796, 4)
# Wall time: 24.9 ms
#    ensembl_gene_id hgnc_symbol  entrezgene_id transcript_biotype
# 1  ENSG00000198888      MT-ND1         4535.0     protein_coding
# 2  ENSG00000198763      MT-ND2         4536.0     protein_coding
# 3  ENSG00000198804      MT-CO1         4512.0     protein_coding
# 4  ENSG00000198712      MT-CO2         4513.0     protein_coding
# 5  ENSG00000228253     MT-ATP8         4509.0     protein_coding

# %%
#Convert the labels to list
normal_samples_labels = normal_tissue_IDs['sample'].to_list()
primary_samples_labels = primary_tumor_IDs['sample'].to_list()

print(len(normal_samples_labels))
print(len(primary_samples_labels))
normal_tissue_IDs.head()
# Out:
# 7429
# 9185
#                      sample                   samples   _sample_type
# 0  GTEX-1117F-0226-SM-5GZZ7  GTEX-1117F-0226-SM-5GZZ7  Normal Tissue
# 1  GTEX-1117F-0426-SM-5EGHI  GTEX-1117F-0426-SM-5EGHI  Normal Tissue
# 2  GTEX-1117F-0526-SM-5EGHJ  GTEX-1117F-0526-SM-5EGHJ  Normal Tissue
# 3  GTEX-1117F-0626-SM-5N9CS  GTEX-1117F-0626-SM-5N9CS  Normal Tissue
# 4  GTEX-1117F-0726-SM-5GIEN  GTEX-1117F-0726-SM-5GIEN  Normal Tissue

# %%
# %%time
#Download the big expression data
path = input_file_directory + "/xenabrowser_brut_data/samples_normal_tissue.tsv"
df_gexpr_all = pandas.read_csv(path, sep = "\t", index_col='sample')

print(df_gexpr_all.shape)
df_gexpr_all.head(2)
# Out:
# (60498, 19131)
# Wall time: 17min 11s
#                    GTEX-S4Q7-0003-SM-3NM8M  TCGA-19-1787-01  TCGA-S9-A7J2-01  \
# sample
# ENSG00000242268.2                  -3.4580          -9.9658           0.2998
# ENSG00000259041.1                  -9.9658          -9.9658          -9.9658
#
#                    GTEX-QV31-1626-SM-2S1QC  TCGA-G3-A3CH-11  TCGA-B5-A5OE-01  \
# sample
# ENSG00000242268.2                  -9.9658          -9.9658          -9.9658
# ENSG00000259041.1                  -9.9658          -9.9658          -9.9658
#
#                    GTEX-13QIC-0011-R1a-SM-5O9CJ  TCGA-B2-5641-11  \
# sample
# ENSG00000242268.2                       -9.9658          -9.9658
# ENSG00000259041.1                       -9.9658          -9.9658
#
#                    GTEX-ZPCL-0126-SM-4WWC8  TARGET-20-PANGDN-09  ...  \
# sample                                                           ...
# ENSG00000242268.2                  -9.9658              -9.9658  ...
# ENSG00000259041.1                  -9.9658              -9.9658  ...
#
#                    TCGA-FI-A2EY-01  TCGA-55-6985-11  TCGA-EJ-5527-01  \
# sample
# ENSG00000242268.2          -4.0350          -2.0529          -9.9658
# ENSG00000259041.1          -9.9658          -9.9658          -9.9658
#
#                    TCGA-G3-A25X-01  TCGA-24-2254-01  GTEX-11ZTS-3326-SM-5LU9Y  \
# sample
# ENSG00000242268.2          -9.9658          -1.9379                    1.5165
# ENSG00000259041.1          -9.9658          -9.9658                   -9.9658
#
#                    GTEX-VJYA-0726-SM-4KL1T  GTEX-ZA64-2126-SM-5Q5A8  \
# sample
# ENSG00000242268.2                  -9.9658                  -2.3884
# ENSG00000259041.1                  -9.9658                  -9.9658
#
#                    GTEX-Q2AG-2826-SM-2HMJQ  GTEX-XV7Q-0426-SM-4BRVN
# sample
# ENSG00000242268.2                   0.0440                  -3.3076
# ENSG00000259041.1                  -9.9658                  -9.9658
#
# [2 rows x 19131 columns]

# %%
# %%time
#remove dot in ENSEMBL name. Function split created at the beginning
#remove dot in ens name
df_gexpr_all = df_gexpr_all.reset_index()
df_gexpr_all["sample"] = df_gexpr_all["sample"].apply(split)
#see if have duplicate
print('number of duplicated genes:', df_gexpr_all.duplicated('sample').sum())

#Merge with prot coding list
df_gexpr_all.rename(columns = {'sample' : 'ensembl_gene_id'}, inplace = True)
dfmerged = protein_coding_list.merge(df_gexpr_all)
print(dfmerged.shape)
dfmerged.head()
# Out:
# number of duplicated genes: 0
# (19536, 19135)
# Wall time: 5min 7s
#    ensembl_gene_id hgnc_symbol  entrezgene_id transcript_biotype  \
# 0  ENSG00000198888      MT-ND1         4535.0     protein_coding
# 1  ENSG00000198763      MT-ND2         4536.0     protein_coding
# 2  ENSG00000198804      MT-CO1         4512.0     protein_coding
# 3  ENSG00000198712      MT-CO2         4513.0     protein_coding
# 4  ENSG00000228253     MT-ATP8         4509.0     protein_coding
#
#    GTEX-S4Q7-0003-SM-3NM8M  TCGA-19-1787-01  TCGA-S9-A7J2-01  \
# 0                  11.9390          13.1286          12.9213
# 1                  11.7935          13.0793          12.7126
# 2                  13.2552          14.2737          14.6332
# 3                  13.1754          13.8226          14.1272
# 4                  13.3384          13.7528          14.2603
#
#    GTEX-QV31-1626-SM-2S1QC  TCGA-G3-A3CH-11  TCGA-B5-A5OE-01  ...  \
# 0                  12.3347          13.3366          10.0615  ...
# 1                  12.9118          13.4186           9.8850  ...
# 2                  13.8809          15.1213          11.8111  ...
# 3                  13.4472          14.1668          12.4268  ...
# 4                  14.3452          14.4479           9.6767  ...
#
#    TCGA-FI-A2EY-01  TCGA-55-6985-11  TCGA-EJ-5527-01  TCGA-G3-A25X-01  \
# 0          13.9398          12.9477          11.8238           9.8547
# 1          14.3906          13.0265          11.7369           9.3562
# 2          16.2010          14.3892          13.2505          12.3177
# 3          16.0375          13.7841          12.8824          12.2685
# 4          15.4617          14.4888          13.3453           8.5672
#
#    TCGA-24-2254-01  GTEX-11ZTS-3326-SM-5LU9Y  GTEX-VJYA-0726-SM-4KL1T  \
# 0          13.2571                   13.0066                  12.2818
# 1          13.0466                   13.5249                  12.6554
# 2          14.0304                   13.9959                  13.6352
# 3          12.9920                   14.1407                  14.1557
# 4          13.2759                   15.0760                  14.0067
#
#    GTEX-ZA64-2126-SM-5Q5A8  GTEX-Q2AG-2826-SM-2HMJQ  GTEX-XV7Q-0426-SM-4BRVN
# 0                  13.3569                  14.3486                  11.6654
# 1                  13.9404                  14.7075                  12.8655
# 2                  13.6829                  13.5255                  12.1067
# 3                  13.9829                  14.6809                  13.1131
# 4                  14.8292                  14.8795                  13.7038
#
# [5 rows x 19135 columns]

# %%
#Control of the merge. See value of ENSG00000198712 before merging
print(df_gexpr_all.loc[df_gexpr_all['ensembl_gene_id'] == 'ENSG00000198712'])

#Control of the merge. See value of ENSG00000198712 after merging. have to be the same
print(dfmerged.loc[dfmerged['ensembl_gene_id'] == 'ENSG00000198712'])
# Out:
#        ensembl_gene_id  GTEX-S4Q7-0003-SM-3NM8M  TCGA-19-1787-01  \
# 28551  ENSG00000198712                  13.1754          13.8226
#
#        TCGA-S9-A7J2-01  GTEX-QV31-1626-SM-2S1QC  TCGA-G3-A3CH-11  \
# 28551          14.1272                  13.4472          14.1668
#
#        TCGA-B5-A5OE-01  GTEX-13QIC-0011-R1a-SM-5O9CJ  TCGA-B2-5641-11  \
# 28551          12.4268                       15.5831          14.5249
#
#        GTEX-ZPCL-0126-SM-4WWC8  ...  TCGA-FI-A2EY-01  TCGA-55-6985-11  \
# 28551                  14.2214  ...          16.0375          13.7841
#
#        TCGA-EJ-5527-01  TCGA-G3-A25X-01  TCGA-24-2254-01  \
# 28551          12.8824          12.2685           12.992
#
#        GTEX-11ZTS-3326-SM-5LU9Y  GTEX-VJYA-0726-SM-4KL1T  \
# 28551                   14.1407                  14.1557
#
#        GTEX-ZA64-2126-SM-5Q5A8  GTEX-Q2AG-2826-SM-2HMJQ  \
# 28551                  13.9829                  14.6809
#
#        GTEX-XV7Q-0426-SM-4BRVN
# 28551                  13.1131
#
# [1 rows x 19132 columns]
#    ensembl_gene_id hgnc_symbol  entrezgene_id transcript_biotype  \
# 3  ENSG00000198712      MT-CO2         4513.0     protein_coding
#
#    GTEX-S4Q7-0003-SM-3NM8M  TCGA-19-1787-01  TCGA-S9-A7J2-01  \
# 3                  13.1754          13.8226          14.1272
#
#    GTEX-QV31-1626-SM-2S1QC  TCGA-G3-A3CH-11  TCGA-B5-A5OE-01  ...  \
# 3                  13.4472          14.1668          12.4268  ...
#
#    TCGA-FI-A2EY-01  TCGA-55-6985-11  TCGA-EJ-5527-01  TCGA-G3-A25X-01  \
# 3          16.0375          13.7841          12.8824          12.2685
#
#    TCGA-24-2254-01  GTEX-11ZTS-3326-SM-5LU9Y  GTEX-VJYA-0726-SM-4KL1T  \
# 3           12.992                   14.1407                  14.1557
#
#    GTEX-ZA64-2126-SM-5Q5A8  GTEX-Q2AG-2826-SM-2HMJQ  GTEX-XV7Q-0426-SM-4BRVN
# 3                  13.9829                  14.6809                  13.1131
#
# [1 rows x 19135 columns]

# %%
# %%time
#keep the gene_ids
df_part1 = dfmerged.iloc[:,0:4]

#Do subset
normal_protcoding = dfmerged.iloc[:,4:][normal_samples_labels]
primary_protcoding = dfmerged.iloc[:,4:][primary_samples_labels]

normal_protcoding = pandas.concat([df_part1, normal_protcoding], axis=1)
primary_protcoding = pandas.concat([df_part1, primary_protcoding], axis=1)

print(normal_protcoding.shape)
print(primary_protcoding.shape)
normal_protcoding.head(2)
# Out:
# (19536, 7433)
# (19536, 9189)
# Wall time: 4.41 s
#    ensembl_gene_id hgnc_symbol  entrezgene_id transcript_biotype  \
# 0  ENSG00000198888      MT-ND1         4535.0     protein_coding
# 1  ENSG00000198763      MT-ND2         4536.0     protein_coding
#
#    GTEX-1117F-0226-SM-5GZZ7  GTEX-1117F-0426-SM-5EGHI  \
# 0                   13.1350                   14.6712
# 1                   12.6215                   14.2931
#
#    GTEX-1117F-0526-SM-5EGHJ  GTEX-1117F-0626-SM-5N9CS  \
# 0                   12.8924                   12.6263
# 1                   12.6612                   13.0833
#
#    GTEX-1117F-0726-SM-5GIEN  GTEX-1117F-1326-SM-5EGHH  ...  \
# 0                   13.8339                   13.7962  ...
# 1                   14.1782                   13.8157  ...
#
#    GTEX-ZZPU-0726-SM-5N9C8  GTEX-ZZPU-0926-SM-5GZYT  GTEX-ZZPU-1226-SM-5N9CK  \
# 0                  12.8565                  14.8073                  14.3240
# 1                  13.0353                  14.6549                  14.3492
#
#    GTEX-ZZPU-1326-SM-5GZWS  GTEX-ZZPU-1426-SM-5GZZ6  GTEX-ZZPU-1826-SM-5E43L  \
# 0                  14.0776                  14.1602                  13.7105
# 1                  14.2711                  14.3810                  14.2432
#
#    GTEX-ZZPU-2126-SM-5EGIU  GTEX-ZZPU-2226-SM-5EGIV  GTEX-ZZPU-2626-SM-5E45Y  \
# 0                  12.8758                  12.5436                  14.6088
# 1                  13.3940                  12.8245                  14.2491
#
#    GTEX-ZZPU-2726-SM-5NQ8O
# 0                  14.3228
# 1                  14.3830
#
# [2 rows x 7433 columns]

# %%
primary_protcoding.head(2)
# Out:
#    ensembl_gene_id hgnc_symbol  entrezgene_id transcript_biotype  \
# 0  ENSG00000198888      MT-ND1         4535.0     protein_coding
# 1  ENSG00000198763      MT-ND2         4536.0     protein_coding
#
#    TCGA-02-0047-01  TCGA-02-0055-01  TCGA-02-2483-01  TCGA-02-2485-01  \
# 0          12.9202          10.3972          11.6941          10.4295
# 1          13.1220          10.7774          12.0249          10.5171
#
#    TCGA-04-1331-01  TCGA-04-1332-01  ...  TCGA-ZP-A9D4-01  TCGA-ZQ-A9CR-01  \
# 0          14.0694          11.2467  ...          14.1228          14.1494
# 1          14.6290          10.8930  ...          14.3408          14.5528
#
#    TCGA-ZR-A9CJ-01  TCGA-ZS-A9CD-01  TCGA-ZS-A9CE-01  TCGA-ZS-A9CF-01  \
# 0          12.7135          12.2320          12.4638          13.0252
# 1          13.7231          11.7949          12.5317          13.2492
#
#    TCGA-ZS-A9CG-01  TCGA-ZT-A8OM-01  TCGA-ZU-A8S4-01  TCGA-ZX-AA5X-01
# 0          12.1005           9.1004          11.3570          13.1548
# 1          12.7117           8.4127          11.6873          13.1203
#
# [2 rows x 9189 columns]

# %%
#test if everything is still good after concat and subset
print(dfmerged['TCGA-ZS-A9CG-01'][12])
print(primary_protcoding['TCGA-ZS-A9CG-01'][12])
# Out:
# 13.2461
# 13.2461

# %%
print("Normal tissue")
print("is nan in ensembl:", normal_protcoding['ensembl_gene_id'].isna().sum())
print('number of duplicate:',normal_protcoding.duplicated('ensembl_gene_id').sum())
print("is nan in symbol:",normal_protcoding['hgnc_symbol'].isna().sum())
print('number of duplicate:',normal_protcoding.duplicated('hgnc_symbol').sum())
print("is nan in entrezgene_id:", normal_protcoding['entrezgene_id'].isna().sum())
print('number of duplicate:',normal_protcoding.duplicated('entrezgene_id').sum())

print("Primary Tumor")
print("is nan in ensembl:", primary_protcoding['ensembl_gene_id'].isna().sum())
print('number of duplicate:',primary_protcoding.duplicated('ensembl_gene_id').sum())
print("is nan in symbol:",primary_protcoding['hgnc_symbol'].isna().sum())
print('number of duplicate:',primary_protcoding.duplicated('hgnc_symbol').sum()
print("is nan in entrezgene_id:", primary_protcoding['entrezgene_id'].isna().sum())
print('number of duplicate:',primary_protcoding.duplicated('entrezgene_id').sum()

# %%
#see how many duplicates in genes
print('normal shape:', normal_protcoding.shape)
print('number of duplicate:',normal_protcoding.duplicated('ensembl_gene_id').sum())
print()
print('primary shape is:', primary_protcoding.shape)
print('number of duplicate:',primary_protcoding.duplicated('ensembl_gene_id').sum())
print()

#delete duplicates
normal_protcoding.drop_duplicates(subset = "ensembl_gene_id", inplace = True)
primary_protcoding.drop_duplicates(subset = "ensembl_gene_id", inplace = True)

# save to csv To not do the top again. My RAM is too low to run in a One shot
path = 'ATG7/dataframes_for_input/'
normal_protcoding.to_csv(output_file_directory+path+'not_complete_normal_protcoding_expr.csv',sep = ",", index=False)
primary_protcoding.to_csv(output_file_directory+path+'not_complete_primary_protcoding_expr.csv',sep = ",", index=False)
# Out:
# normal shape: (19536, 7433)
# number of duplicate: 154
#
# primary shape is: (19536, 9189)
# number of duplicate: 154
#
# Where are from duplicates??? there were ZERO duplicate before the merge, and I know my merge is correct

# %%
# %%time
path = output_file_directory + path = 'ATG7/dataframes_for_input/'
normal_protcoding= pandas.read_csv(path+'not_complete_normal_protcoding_expr.csv', sep = ",")
primary_protcoding= pandas.read_csv(path+'not_complete_primary_protcoding_expr.csv', sep = ",")

print(normal_protcoding.shape)
print(primary_protcoding.shape)

normal_protcoding.head()

# %%
normal_protcoding.head()
# Out:
#    ensembl_gene_id hgnc_symbol  entrezgene_id transcript_biotype  \
# 0  ENSG00000198888      MT-ND1         4535.0     protein_coding
# 1  ENSG00000198763      MT-ND2         4536.0     protein_coding
# 2  ENSG00000198804      MT-CO1         4512.0     protein_coding
# 3  ENSG00000198712      MT-CO2         4513.0     protein_coding
# 4  ENSG00000228253     MT-ATP8         4509.0     protein_coding
#
#    GTEX-1117F-0226-SM-5GZZ7  GTEX-1117F-0426-SM-5EGHI  \
# 0                   13.1350                   14.6712
# 1                   12.6215                   14.2931
# 2                   12.6246                   14.5995
# 3                   12.8384                   14.7048
# 4                   13.9763                   15.7851
#
#    GTEX-1117F-0526-SM-5EGHJ  GTEX-1117F-0626-SM-5N9CS  \
# 0                   12.8924                   12.6263
# 1                   12.6612                   13.0833
# 2                   12.5008                   11.3334
# 3                   12.8456                   12.6928
# 4                   13.9252                   14.1037
#
#    GTEX-1117F-0726-SM-5GIEN  GTEX-1117F-1326-SM-5EGHH  ...  \
# 0                   13.8339                   13.7962  ...
# 1                   14.1782                   13.8157  ...
# 2                   15.3590                   12.2692  ...
# 3                   14.8495                   13.4601  ...
# 4                   16.3241                   15.3932  ...
#
#    GTEX-ZZPU-0726-SM-5N9C8  GTEX-ZZPU-0926-SM-5GZYT  GTEX-ZZPU-1226-SM-5N9CK  \
# 0                  12.8565                  14.8073                  14.3240
# 1                  13.0353                  14.6549                  14.3492
# 2                  13.3965                  15.9901                  15.2750
# 3                  13.3606                  15.3773                  14.9873
# 4                  14.3118                  16.4238                  15.5251
#
#    GTEX-ZZPU-1326-SM-5GZWS  GTEX-ZZPU-1426-SM-5GZZ6  GTEX-ZZPU-1826-SM-5E43L  \
# 0                  14.0776                  14.1602                  13.7105
# 1                  14.2711                  14.3810                  14.2432
# 2                  15.1726                  14.8551                  14.6084
# 3                  14.6528                  14.7760                  14.8340
# 4                  15.8844                  15.8104                  15.4948
#
#    GTEX-ZZPU-2126-SM-5EGIU  GTEX-ZZPU-2226-SM-5EGIV  GTEX-ZZPU-2626-SM-5E45Y  \
# 0                  12.8758                  12.5436                  14.6088
# 1                  13.3940                  12.8245                  14.2491
# 2                  13.5241                  14.0931                  15.5290
# 3                  13.4387                  14.1687                  15.1614
# 4                  14.9172                  14.8163                  16.0166
#
#    GTEX-ZZPU-2726-SM-5NQ8O
# 0                  14.3228
# 1                  14.3830
# 2                  14.3970
# 3                  14.3728
# 4                  15.2887
#
# [5 rows x 7433 columns]

# %% [markdown]
# ## A) ENSEMBL

# %%
# %%time
#Preparation of the global dataframe
protcoding_final = []
data = [not_complete_normal_protcoding, not_complete_primary_protcoding]

for df in data:
    #transpose the table 
    df = numpy.transpose(df)

    #Change head column & delete the name of the column index; choose ENSEMBL
    df.columns = df.iloc[0]
    df.columns.name = None
    df = df.reset_index()

    #Delete the first rows & columns rename to merge 
    df = df.drop(df.index[0:4])
    df.rename(columns = {'index' : 'sample'}, inplace = True)

    protcoding_final.append(df)
    
ensembl_normal_protcoding_expr = protcoding_final[0]
ensembl_primary_protcoding_expr = protcoding_final[1]

print('normal shape =', ensembl_normal_protcoding_expr.shape)
print('primary shape =', ensembl_primary_protcoding_expr.shape)
normal_protcoding.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7ef4fef113c8> in <module>
#      20 normal_protcoding = protcoding_final[0]
#      21 primary_protcoding = protcoding_final[1]
# ---> 22 protcoding_df.head()
#
# NameError: name 'protcoding_df' is not defined

# %%
#save to csv
path = 'ATG7/dataframes_for_input/'
ensembl_normal_protcoding_expr.to_csv(output_file_directory+path+'ensembl_normal_protcoding_expr.csv',sep = ",", index=False)
ensembl_primary_protcoding_expr.to_csv(output_file_directory+path+'ensembl_primary_protcoding_expr.csv',sep = ",", index=False)

# %% [markdown]
# ## B) SYMBOLS

# %%
# %%time
#Preparation of the global dataframe
protcoding_final = []
data = [normal_protcoding, primary_protcoding]

for df in data:
    df = df.dropna(subset=['hgnc_symbol'])
    #transpose the table 
    df = numpy.transpose(df)

    #Change head column & delete the name of the column index; choose ENSEMBL
    df.columns = df.iloc[1]
    df.columns.name = None
    df = df.reset_index()

    #Delete the first rows & columns rename to merge 
    df = df.drop(df.index[0:4])
    df.rename(columns = {'index' : 'sample'}, inplace = True)

    protcoding_final.append(df)
    
symbol_normal_protcoding = protcoding_final[0]
symbol_primary_protcoding = protcoding_final[1]

print('normal shape =', symbol_normal_protcoding.shape)
print('primary shape =', symbol_primary_protcoding.shape)
symbol_normal_protcoding.head()
# Out:
# normal shape = (7429, 19190)
# primary shape = (9185, 19190)
# Wall time: 2min 17s
#                      sample   MT-ND1   MT-ND2   MT-CO1   MT-CO2  MT-ATP8  \
# 4  GTEX-1117F-0226-SM-5GZZ7   13.135  12.6215  12.6246  12.8384  13.9763
# 5  GTEX-1117F-0426-SM-5EGHI  14.6712  14.2931  14.5995  14.7048  15.7851
# 6  GTEX-1117F-0526-SM-5EGHJ  12.8924  12.6612  12.5008  12.8456  13.9252
# 7  GTEX-1117F-0626-SM-5N9CS  12.6263  13.0833  11.3334  12.6928  14.1037
# 8  GTEX-1117F-0726-SM-5GIEN  13.8339  14.1782   15.359  14.8495  16.3241
#
#    MT-ATP6   MT-CO3   MT-ND3  MT-ND4L  ...  S100A1   CHTOP  SNAPIN  SH3D21  \
# 4  13.1286  13.5276  11.9137  12.0779  ...   4.284  5.3992  5.3851  4.6247
# 5  15.3795  15.3725  13.0616  13.6227  ...  7.7997  4.4357  4.5802  1.5563
# 6  13.3517  13.4492  11.6795  12.2196  ...  0.5568  5.1692   4.701  2.8522
# 7  13.4508  13.2862  12.9488  12.1293  ...  2.7292  5.9507  5.6177  1.4441
# 8  16.1573  15.4759  14.3121   14.432  ...  9.0834  5.1086  4.6095  2.5948
#
#     STK40   LSM10   OSCP1  MRPS15   CSF3R   EVA1B
# 4  4.8258  5.4912  3.1294  5.6224  4.5663  6.4249
# 5  4.8365  6.3473  2.4597  6.6948  0.8568  2.8055
# 6  5.6065  4.9801  2.1411  4.9824  2.4675    5.55
# 7  5.1392  5.2791  2.5707  5.7211   4.178  6.3669
# 8  3.9947  4.6849  2.3135       5  4.0091  3.9421
#
# [5 rows x 19190 columns]

# %%
#save to csv
path = 'ATG7/dataframes_for_input/'
symbol_normal_protcoding.to_csv(output_file_directory+path+'symbol_normal_protcoding_expr.csv',sep = ",", index=False)
symbol_primary_protcoding.to_csv(output_file_directory+path+'symbol_primary_protcoding_expr.csv',sep = ",", index=False)
